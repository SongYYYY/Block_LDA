# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt 
import random 
import networkx as nx 
import itertools 
import pickle 
from scipy.special import digamma
import timeit

# %% [markdown]
# # load data

# %%
# cora dataset
G_cora=nx.read_adjlist('data/Cora_enrich/idx_adjlist.txt',nodetype=int,create_using=nx.DiGraph)
# subgraph from G ,with nodes {0-99}
G_cora_mini=G_cora.subgraph(list(range(100)))
# cora texts
texts_cora=np.loadtxt('data/Cora_enrich/BOW_texts_3876.txt',dtype=np.int)
texts_cora_mini=texts_cora[:100,:]

# %% [markdown]
# # Block_PLSA

# %% [markdown]
# ## utils

# %%
def index2ij(index,K):
    row=int(index/K) 
    col=index%K
    return row,col

# %% [markdown]
# ## input tranformation

# %%
# transfer input to observed variables
# PLSA part
ii,jj=np.nonzero(texts_cora)
WS=np.repeat(jj,texts_cora[ii,jj])
DS=np.repeat(ii,texts_cora[ii,jj])
# blockmodel part
SS=[]
RS=[]
for e in G_cora.edges:
    SS.append(e[0])
    RS.append(e[1])
SS=np.array(SS,dtype=np.int)
RS=np.array(RS,dtype=np.int)

# %%
# help utils
D_ids={}
for idx,d in enumerate(DS):
    if d in D_ids:
        D_ids[d].append(idx)
    else:
        D_ids[d]=[idx]
        
S_ids={}
for idx,s in enumerate(SS):
    if s in S_ids:
        S_ids[s].append(idx)
    else:
        S_ids[s]=[idx]
        
R_ids={}
for idx,r in enumerate(RS):
    if r in R_ids:
        R_ids[r].append(idx)
    else:
        R_ids[r]=[idx]
         
W_ids={}
for idx,w in enumerate(WS):
    if w in W_ids:
        W_ids[w].append(idx)
    else:
        W_ids[w]=[idx]

# %% [markdown]
# ## initialization

# %%
# model hyperparameters 
alpha=1e-2
K=7
D=texts_cora.shape[0]
V=texts_cora.shape[1]
L=len(SS)
N=len(WS)
# runtime parameters
n_iter_EM=30
n_iter_VI=100
gamma_max_gap=0.2
phi_max_gap=K*V*0.0001

# %%
# Initialize EM parameters
omega=np.zeros((K,D))
omega[:]=1/D
phi=np.zeros((K,V))
phi[:]=1/V
pi=np.zeros(K)
pi[:]=1/K 
    
# initialize VI parameters
gamma=np.zeros(K**2)
gamma[:]=1e-1
delta=np.zeros((L,K**2))
delta[:]=1/K**2
epsilon=np.zeros((N,K))
epsilon[:]=1/K

# %%
# Initialize EM parameters randomly (use diriclet to ensure normalization)
beta=1e-1

omega=np.zeros((K,D))
for k in range(K):
    omega[k,:]=stats.dirichlet.rvs(np.repeat(beta,D))
    
phi=np.zeros((K,V))
for k in range(K):
    phi[k,:]=stats.dirichlet.rvs(np.repeat(beta,V))
    
pi=stats.dirichlet.rvs(np.repeat(beta,K)).flatten()
    
# initialize VI parameters
gamma=stats.dirichlet.rvs(np.repeat(beta,K**2))

delta=np.zeros((L,K**2))
for l in range(L):
    delta[l,:]=stats.dirichlet.rvs(np.repeat(beta,K**2))

epsilon=np.zeros((N,K))
for n in range(N):
    epsilon[n,:]=stats.dirichlet.rvs(np.repeat(beta,K))

# %%
# Initialize parameters randomly
# EM parameters
omega=np.random.randint(1,10,(K,D))
omega=omega/omega.sum(axis=1)[:,np.newaxis]
phi=np.random.randint(1,10,(K,V))
phi=phi/phi.sum(axis=1)[:,np.newaxis]
pi=np.random.randint(1,10,K)
pi=pi/pi.sum() 
    
# VI parameters
gamma=np.repeat(1e-2,K**2)
delta=np.random.randint(1,10,(L,K**2))
delta=delta/delta.sum(axis=1)[:,np.newaxis]
epsilon=np.random.randint(1,10,(N,K))
epsilon=epsilon/epsilon.sum(axis=1)[:,np.newaxis]

# %%
# variational-EM
for it_em in range(n_iter_EM):
    # E-step
    for it_vi in range(n_iter_VI):
        gamma_last=gamma[:]
        # solve gamma&delta
        #gamma=np.array([alpha+delta[:,k].sum() for k in range(K**2)])
        
        gamma=delta.sum(axis=0)+alpha
        
        #delta=np.array([[omega[index2ij(k,K)[0],SS[l]]*omega[index2ij(k,K)[1],RS[l]]*np.exp(digamma(gamma[k])) for k in range(K**2)]\
                        #for l in range(L)])
        
        for k in range(K**2):
            delta[:,k]=omega[index2ij(k,K)[0],SS[range(L)]]*omega[index2ij(k,K)[1],RS[range(L)]]*np.exp(digamma(gamma[k]))
        
        delta=delta/delta.sum(axis=1)[:,np.newaxis]
        # check convergence 
        gamma_gap=np.abs(gamma-gamma_last).sum()
        print('iter:%d,gamma_gap:%f'%(it_vi,gamma_gap))
        if gamma_gap<gamma_max_gap:
            break
        
    # solve epsilon  
    start=timeit.default_timer()
    #epsilon=np.array([[omega[k,DS[n]]*phi[k,WS[n]]*pi[k] for k in range(K)] for n in range(N)])
    
    for k in range(K):
        epsilon[:,k]=omega[k,DS[range(N)]]*phi[k,WS[range(N)]]*pi[k]
    
    epsilon=epsilon/epsilon.sum(axis=1)[:,np.newaxis]
    end=timeit.default_timer()
    print('epsilon time:%s'%str(end-start))
    # M-step
    phi_last=phi.copy()
    pi_last=pi[:]
    omega_last=omega.copy() 
    # omega
    start=timeit.default_timer()
    S_dist=np.zeros((L,K))
    R_dist=np.zeros((L,K))
    for l in range(L):
        S_dist[l,:]=delta[l,:].reshape(K,K).sum(axis=1)
        R_dist[l,:]=delta[l,:].reshape(K,K).sum(axis=0)
    term_1=term_2=term_3=0
    
    for d in range(D):
        ep_id=D_ids.get(d,[])
        term_1=epsilon[ep_id,:].sum(axis=0)
        S_id=S_ids.get(d,[])
        term_2=S_dist[S_id,:].sum(axis=0)
        R_id=R_ids.get(d,[])
        term_3=R_dist[R_id,:].sum(axis=0)
        omega[:,d]=term_1+term_2+term_3
    omega=omega/omega.sum(axis=1)[:,np.newaxis]
    end=timeit.default_timer()
    print('omega time:%s'%str(end-start))
    # phi
    start=timeit.default_timer()
           
    for w in range(V):
        ep_id=W_ids.get(w,[])
        phi[:,w]=epsilon[ep_id,:].sum(axis=0)
    phi=phi/phi.sum(axis=1)[:,np.newaxis]
    end=timeit.default_timer()
    print('phi time:%s'%str(end-start))
    
    # pi
    start=timeit.default_timer()
    pi=epsilon.sum(axis=0)
    pi=pi/pi.sum()
    end=timeit.default_timer()
    print('pi time:%s'%str(end-start))
    # check convergence
    phi_gap=np.abs(phi-phi_last).sum()
    pi_gap=np.abs(pi-pi_last).sum()
    omega_gap=np.abs(omega-omega_last).sum() 
    print('iter:%d,phi_gap:%f,pi_gap:%f,omega_gap:%f'%(it_em,phi_gap,pi_gap,omega_gap))
    if phi_gap<phi_max_gap:
        #break 
        pass
# Out:
# iter:0,gamma_gap:5428.490000
# iter:1,gamma_gap:540.556730
# iter:2,gamma_gap:236.172073
# iter:3,gamma_gap:122.593474
# iter:4,gamma_gap:72.095380
# iter:5,gamma_gap:46.625527
# iter:6,gamma_gap:31.077203
# iter:7,gamma_gap:21.095841
# iter:8,gamma_gap:14.380286
# iter:9,gamma_gap:9.847435
# iter:10,gamma_gap:6.788282
# iter:11,gamma_gap:4.715963
# iter:12,gamma_gap:3.301267
# iter:13,gamma_gap:2.338076
# iter:14,gamma_gap:1.662006
# iter:15,gamma_gap:1.185525
# iter:16,gamma_gap:0.848382
# iter:17,gamma_gap:0.608938
# iter:18,gamma_gap:0.438287
# iter:19,gamma_gap:0.316270
# iter:20,gamma_gap:0.228765
# iter:21,gamma_gap:0.166390
# epsilon time:3.846603199999663
# omega time:0.26490259999991395
# phi time:0.23404470000059518
# pi time:0.030825899999399553
# iter:0,phi_gap:10.132278,pi_gap:0.878802,omega_gap:8.996097
# iter:0,gamma_gap:0.121542
# epsilon time:3.868558199999825
# omega time:0.2519212000006519
# phi time:0.2196524999999383
# pi time:0.03331689999868104
# iter:1,phi_gap:1.261946,pi_gap:0.022776,omega_gap:1.244581
# iter:0,gamma_gap:938.442137
# iter:1,gamma_gap:496.663630
# iter:2,gamma_gap:385.304438
# iter:3,gamma_gap:306.994563
# iter:4,gamma_gap:254.841605
# iter:5,gamma_gap:215.918271
# iter:6,gamma_gap:183.704739
# iter:7,gamma_gap:157.702184
# iter:8,gamma_gap:135.870877
# iter:9,gamma_gap:117.492071
# iter:10,gamma_gap:102.102847
# iter:11,gamma_gap:89.155334
# iter:12,gamma_gap:78.146817
# iter:13,gamma_gap:68.854197
# iter:14,gamma_gap:60.953757
# iter:15,gamma_gap:54.853844
# iter:16,gamma_gap:50.269874
# iter:17,gamma_gap:46.371304
# iter:18,gamma_gap:42.931968
# iter:19,gamma_gap:39.931685
# iter:20,gamma_gap:37.248763
# iter:21,gamma_gap:34.843234
# iter:22,gamma_gap:32.830548
# iter:23,gamma_gap:31.004021
# iter:24,gamma_gap:29.291747
# iter:25,gamma_gap:27.590623
# iter:26,gamma_gap:26.256927
# iter:27,gamma_gap:25.188817
# iter:28,gamma_gap:24.226715
# iter:29,gamma_gap:23.341614
# iter:30,gamma_gap:22.529795
# iter:31,gamma_gap:21.746093
# iter:32,gamma_gap:20.879066
# iter:33,gamma_gap:20.010653
# iter:34,gamma_gap:19.427920
# iter:35,gamma_gap:18.889498
# iter:36,gamma_gap:18.377953
# iter:37,gamma_gap:17.912210
# iter:38,gamma_gap:17.467446
# iter:39,gamma_gap:17.038585
# iter:40,gamma_gap:16.624391
# iter:41,gamma_gap:16.200740
# iter:42,gamma_gap:15.688658
# iter:43,gamma_gap:15.050490
# iter:44,gamma_gap:14.699882
# iter:45,gamma_gap:14.408928
# iter:46,gamma_gap:14.125699
# iter:47,gamma_gap:13.850890
# iter:48,gamma_gap:13.584469
# iter:49,gamma_gap:13.325817
# iter:50,gamma_gap:13.073530
# iter:51,gamma_gap:12.824650
# iter:52,gamma_gap:12.575443
# iter:53,gamma_gap:12.314475
# iter:54,gamma_gap:11.964061
# iter:55,gamma_gap:11.378302
# iter:56,gamma_gap:10.760503
# iter:57,gamma_gap:10.367776
# iter:58,gamma_gap:10.199367
# iter:59,gamma_gap:10.039095
# iter:60,gamma_gap:9.880556
# iter:61,gamma_gap:9.722445
# iter:62,gamma_gap:9.565785
# iter:63,gamma_gap:9.411188
# iter:64,gamma_gap:9.259029
# iter:65,gamma_gap:9.109547
# iter:66,gamma_gap:8.962893
# iter:67,gamma_gap:8.819161
# iter:68,gamma_gap:8.678404
# iter:69,gamma_gap:8.540649
# iter:70,gamma_gap:8.405904
# iter:71,gamma_gap:8.274163
# iter:72,gamma_gap:8.145410
# iter:73,gamma_gap:8.019620
# iter:74,gamma_gap:7.896766
# iter:75,gamma_gap:7.776814
# iter:76,gamma_gap:7.659731
# iter:77,gamma_gap:7.545478
# iter:78,gamma_gap:7.434015
# iter:79,gamma_gap:7.325301
# iter:80,gamma_gap:7.219290
# iter:81,gamma_gap:7.115934
# iter:82,gamma_gap:7.015180
# iter:83,gamma_gap:6.916966
# iter:84,gamma_gap:6.821219
# iter:85,gamma_gap:6.727853
# iter:86,gamma_gap:6.636752
# iter:87,gamma_gap:6.551127
# iter:88,gamma_gap:6.468899
# iter:89,gamma_gap:6.388680
# iter:90,gamma_gap:6.309380
# iter:91,gamma_gap:6.229953
# iter:92,gamma_gap:6.148311
# iter:93,gamma_gap:6.059675
# iter:94,gamma_gap:5.950852
# iter:95,gamma_gap:5.775754
# iter:96,gamma_gap:5.399554
# iter:97,gamma_gap:5.006819
# iter:98,gamma_gap:4.622560
# iter:99,gamma_gap:4.430953
# epsilon time:4.569318699999712
# omega time:0.27658060000067053
# phi time:0.23390459999973245
# pi time:0.031986800000595395
# iter:2,phi_gap:0.700244,pi_gap:0.012095,omega_gap:0.676212
# iter:0,gamma_gap:4.380041
# iter:1,gamma_gap:183.396601
# iter:2,gamma_gap:101.029686
# iter:3,gamma_gap:64.847058
# iter:4,gamma_gap:48.386355
# iter:5,gamma_gap:40.305081
# iter:6,gamma_gap:34.753994
# iter:7,gamma_gap:31.118152
# iter:8,gamma_gap:28.315738
# iter:9,gamma_gap:26.165487
# iter:10,gamma_gap:24.424504
# iter:11,gamma_gap:22.943524
# iter:12,gamma_gap:21.590675
# iter:13,gamma_gap:20.217491
# iter:14,gamma_gap:19.116620
# iter:15,gamma_gap:18.211464
# iter:16,gamma_gap:17.562371
# iter:17,gamma_gap:17.019746
# iter:18,gamma_gap:16.517056
# iter:19,gamma_gap:16.059469
# iter:20,gamma_gap:15.634609
# iter:21,gamma_gap:15.237255
# iter:22,gamma_gap:14.872589
# iter:23,gamma_gap:14.532382
# iter:24,gamma_gap:14.212368
# iter:25,gamma_gap:13.910687
# iter:26,gamma_gap:13.647651
# iter:27,gamma_gap:13.414173
# iter:28,gamma_gap:13.205055
# iter:29,gamma_gap:13.022122
# iter:30,gamma_gap:12.852242
# iter:31,gamma_gap:12.690029
# iter:32,gamma_gap:12.534982
# iter:33,gamma_gap:12.386586
# iter:34,gamma_gap:12.244260
# iter:35,gamma_gap:12.107274
# iter:36,gamma_gap:11.974554
# iter:37,gamma_gap:11.844195
# iter:38,gamma_gap:11.712008
# iter:39,gamma_gap:11.566292
# iter:40,gamma_gap:11.364831
# iter:41,gamma_gap:10.985516
# iter:42,gamma_gap:10.676343
# iter:43,gamma_gap:10.536479
# iter:44,gamma_gap:10.406703
# iter:45,gamma_gap:10.283191
# iter:46,gamma_gap:10.163739
# iter:47,gamma_gap:10.045380
# iter:48,gamma_gap:9.928519
# iter:49,gamma_gap:9.785437
# iter:50,gamma_gap:9.535052
# iter:51,gamma_gap:9.145753
# iter:52,gamma_gap:9.014423
# iter:53,gamma_gap:8.934969
# iter:54,gamma_gap:8.858907
# iter:55,gamma_gap:8.785444
# iter:56,gamma_gap:8.714695
# iter:57,gamma_gap:8.647432
# iter:58,gamma_gap:8.582349
# iter:59,gamma_gap:8.519554
# iter:60,gamma_gap:8.459122
# iter:61,gamma_gap:8.401095
# iter:62,gamma_gap:8.345475
# iter:63,gamma_gap:8.292217
# iter:64,gamma_gap:8.241218
# iter:65,gamma_gap:8.192289
# iter:66,gamma_gap:8.145101
# iter:67,gamma_gap:8.099075
# iter:68,gamma_gap:8.053147
# iter:69,gamma_gap:8.005169
# iter:70,gamma_gap:7.950193
# iter:71,gamma_gap:7.874434
# iter:72,gamma_gap:7.729131
# iter:73,gamma_gap:7.375081
# iter:74,gamma_gap:7.065807
# iter:75,gamma_gap:6.869937
# iter:76,gamma_gap:6.498301
# iter:77,gamma_gap:6.325011
# iter:78,gamma_gap:6.209527
# iter:79,gamma_gap:5.928705
# iter:80,gamma_gap:5.581878
# iter:81,gamma_gap:5.482703
# iter:82,gamma_gap:5.411664
# iter:83,gamma_gap:5.350856
# iter:84,gamma_gap:5.297072
# iter:85,gamma_gap:5.248406
# iter:86,gamma_gap:5.203651
# iter:87,gamma_gap:5.162239
# iter:88,gamma_gap:5.124316
# iter:89,gamma_gap:5.088184
# iter:90,gamma_gap:5.053632
# iter:91,gamma_gap:5.020512
# iter:92,gamma_gap:4.988721
# iter:93,gamma_gap:4.958185
# iter:94,gamma_gap:4.928852
# iter:95,gamma_gap:4.900678
# iter:96,gamma_gap:4.873629
# iter:97,gamma_gap:4.847672
# iter:98,gamma_gap:4.822772
# iter:99,gamma_gap:4.799320
# epsilon time:4.170506099999329
# omega time:0.3392490000005637
# phi time:0.2838011000003462
# pi time:0.03684810000049765
# iter:3,phi_gap:0.510954,pi_gap:0.008444,omega_gap:0.501470
# iter:0,gamma_gap:4.777099
# iter:1,gamma_gap:149.970717
# iter:2,gamma_gap:77.631163
# iter:3,gamma_gap:50.249434
# iter:4,gamma_gap:39.497322
# iter:5,gamma_gap:33.835957
# iter:6,gamma_gap:30.057841
# iter:7,gamma_gap:27.453138
# iter:8,gamma_gap:25.435614
# iter:9,gamma_gap:23.708569
# iter:10,gamma_gap:22.105841
# iter:11,gamma_gap:20.863504
# iter:12,gamma_gap:19.822640
# iter:13,gamma_gap:18.892372
# iter:14,gamma_gap:18.044659
# iter:15,gamma_gap:17.265892
# iter:16,gamma_gap:16.542815
# iter:17,gamma_gap:15.857671
# iter:18,gamma_gap:15.168110
# iter:19,gamma_gap:14.366587
# iter:20,gamma_gap:13.676226
# iter:21,gamma_gap:13.159175
# iter:22,gamma_gap:12.694702
# iter:23,gamma_gap:12.257085
# iter:24,gamma_gap:11.843038
# iter:25,gamma_gap:11.451104
# iter:26,gamma_gap:11.104861
# iter:27,gamma_gap:10.794469
# iter:28,gamma_gap:10.499447
# iter:29,gamma_gap:10.218745
# iter:30,gamma_gap:9.951426
# iter:31,gamma_gap:9.696651
# iter:32,gamma_gap:9.453668
# iter:33,gamma_gap:9.221802
# iter:34,gamma_gap:9.000445
# iter:35,gamma_gap:8.789050
# iter:36,gamma_gap:8.587118
# iter:37,gamma_gap:8.394198
# iter:38,gamma_gap:8.209877
# iter:39,gamma_gap:8.033781
# iter:40,gamma_gap:7.865566
# iter:41,gamma_gap:7.704915
# iter:42,gamma_gap:7.551541
# iter:43,gamma_gap:7.405178
# iter:44,gamma_gap:7.265581
# iter:45,gamma_gap:7.132524
# iter:46,gamma_gap:7.005801
# iter:47,gamma_gap:6.885217
# iter:48,gamma_gap:6.772895
# iter:49,gamma_gap:6.677197
# iter:50,gamma_gap:6.592173
# iter:51,gamma_gap:6.518309
# iter:52,gamma_gap:6.448984
# iter:53,gamma_gap:6.384037
# iter:54,gamma_gap:6.323259
# iter:55,gamma_gap:6.266344
# iter:56,gamma_gap:6.216869
# iter:57,gamma_gap:6.170935
# iter:58,gamma_gap:6.125548
# iter:59,gamma_gap:6.089063
# iter:60,gamma_gap:6.038004
# iter:61,gamma_gap:5.920232
# iter:62,gamma_gap:5.593439
# iter:63,gamma_gap:5.347149
# iter:64,gamma_gap:5.268627
# iter:65,gamma_gap:5.144796
# iter:66,gamma_gap:4.840234
# iter:67,gamma_gap:4.490403
# iter:68,gamma_gap:4.405261
# iter:69,gamma_gap:4.358573
# iter:70,gamma_gap:4.315595
# iter:71,gamma_gap:4.272697
# iter:72,gamma_gap:4.231510
# iter:73,gamma_gap:4.204241
# iter:74,gamma_gap:4.176097
# iter:75,gamma_gap:4.147485
# iter:76,gamma_gap:4.118705
# iter:77,gamma_gap:4.090329
# iter:78,gamma_gap:4.062881
# iter:79,gamma_gap:4.035283
# iter:80,gamma_gap:4.007763
# iter:81,gamma_gap:3.980495
# iter:82,gamma_gap:3.953613
# iter:83,gamma_gap:3.932207
# iter:84,gamma_gap:3.913556
# iter:85,gamma_gap:3.895309
# iter:86,gamma_gap:3.878230
# iter:87,gamma_gap:3.861737
# iter:88,gamma_gap:3.845844
# iter:89,gamma_gap:3.830579
# iter:90,gamma_gap:3.815967
# iter:91,gamma_gap:3.802028
# iter:92,gamma_gap:3.788781
# iter:93,gamma_gap:3.776243
# iter:94,gamma_gap:3.764592
# iter:95,gamma_gap:3.753958
# iter:96,gamma_gap:3.744061
# iter:97,gamma_gap:3.734910
# iter:98,gamma_gap:3.726512
# iter:99,gamma_gap:3.718870
# epsilon time:4.115444999999454
# omega time:0.2771833999995579
# phi time:0.23247319999973115
# pi time:0.03176859999985027
# iter:4,phi_gap:0.424907,pi_gap:0.007155,omega_gap:0.426544
# iter:0,gamma_gap:3.711987
# iter:1,gamma_gap:146.345911
# iter:2,gamma_gap:69.648828
# iter:3,gamma_gap:45.298703
# iter:4,gamma_gap:37.472529
# iter:5,gamma_gap:33.217532
# iter:6,gamma_gap:30.356777
# iter:7,gamma_gap:28.193504
# iter:8,gamma_gap:26.552019
# iter:9,gamma_gap:25.237422
# iter:10,gamma_gap:24.046739
# iter:11,gamma_gap:22.950399
# iter:12,gamma_gap:21.929774
# iter:13,gamma_gap:20.968198
# iter:14,gamma_gap:20.075404
# iter:15,gamma_gap:19.155369
# iter:16,gamma_gap:18.216949
# iter:17,gamma_gap:17.517793
# iter:18,gamma_gap:16.796150
# iter:19,gamma_gap:15.950087
# iter:20,gamma_gap:15.308752
# iter:21,gamma_gap:14.778662
# iter:22,gamma_gap:14.266461
# iter:23,gamma_gap:13.768033
# iter:24,gamma_gap:13.266168
# iter:25,gamma_gap:12.694190
# iter:26,gamma_gap:12.008521
# iter:27,gamma_gap:11.566249
# iter:28,gamma_gap:11.190619
# iter:29,gamma_gap:10.829999
# iter:30,gamma_gap:10.485121
# iter:31,gamma_gap:10.164221
# iter:32,gamma_gap:9.857957
# iter:33,gamma_gap:9.565439
# iter:34,gamma_gap:9.285897
# iter:35,gamma_gap:9.018593
# iter:36,gamma_gap:8.762836
# iter:37,gamma_gap:8.517980
# iter:38,gamma_gap:8.283424
# iter:39,gamma_gap:8.058610
# iter:40,gamma_gap:7.843017
# iter:41,gamma_gap:7.636162
# iter:42,gamma_gap:7.437593
# iter:43,gamma_gap:7.246888
# iter:44,gamma_gap:7.063652
# iter:45,gamma_gap:6.887657
# iter:46,gamma_gap:6.718903
# iter:47,gamma_gap:6.556522
# iter:48,gamma_gap:6.400342
# iter:49,gamma_gap:6.250313
# iter:50,gamma_gap:6.105771
# iter:51,gamma_gap:5.966470
# iter:52,gamma_gap:5.832179
# iter:53,gamma_gap:5.702680
# iter:54,gamma_gap:5.578099
# iter:55,gamma_gap:5.460367
# iter:56,gamma_gap:5.353947
# iter:57,gamma_gap:5.251964
# iter:58,gamma_gap:5.153392
# iter:59,gamma_gap:5.058098
# iter:60,gamma_gap:4.965956
# iter:61,gamma_gap:4.876845
# iter:62,gamma_gap:4.790652
# iter:63,gamma_gap:4.707270
# iter:64,gamma_gap:4.626596
# iter:65,gamma_gap:4.548534
# iter:66,gamma_gap:4.472992
# iter:67,gamma_gap:4.402725
# iter:68,gamma_gap:4.335737
# iter:69,gamma_gap:4.270794
# iter:70,gamma_gap:4.207838
# iter:71,gamma_gap:4.146811
# iter:72,gamma_gap:4.096566
# iter:73,gamma_gap:4.048403
# iter:74,gamma_gap:4.001680
# iter:75,gamma_gap:3.956369
# iter:76,gamma_gap:3.912442
# iter:77,gamma_gap:3.869874
# iter:78,gamma_gap:3.828637
# iter:79,gamma_gap:3.788707
# iter:80,gamma_gap:3.750059
# iter:81,gamma_gap:3.712669
# iter:82,gamma_gap:3.676513
# iter:83,gamma_gap:3.641565
# iter:84,gamma_gap:3.607803
# iter:85,gamma_gap:3.575199
# iter:86,gamma_gap:3.543727
# iter:87,gamma_gap:3.513357
# iter:88,gamma_gap:3.484055
# iter:89,gamma_gap:3.460679
# iter:90,gamma_gap:3.441645
# iter:91,gamma_gap:3.423279
# iter:92,gamma_gap:3.405507
# iter:93,gamma_gap:3.388219
# iter:94,gamma_gap:3.371677
# iter:95,gamma_gap:3.363276
# iter:96,gamma_gap:3.356755
# iter:97,gamma_gap:3.348630
# iter:98,gamma_gap:3.336998
# iter:99,gamma_gap:3.317351
# epsilon time:4.11357020000105
# omega time:0.27598439999928814
# phi time:0.23013900000114518
# pi time:0.03186930000083521
# iter:5,phi_gap:0.384602,pi_gap:0.006713,omega_gap:0.394139
# iter:0,gamma_gap:3.276777
# iter:1,gamma_gap:129.490547
# iter:2,gamma_gap:64.765713
# iter:3,gamma_gap:47.393352
# iter:4,gamma_gap:39.704477
# iter:5,gamma_gap:35.113460
# iter:6,gamma_gap:31.926670
# iter:7,gamma_gap:29.502495
# iter:8,gamma_gap:27.581970
# iter:9,gamma_gap:25.929598
# iter:10,gamma_gap:24.474850
# iter:11,gamma_gap:23.214272
# iter:12,gamma_gap:22.106104
# iter:13,gamma_gap:21.190552
# iter:14,gamma_gap:20.352542
# iter:15,gamma_gap:19.585015
# iter:16,gamma_gap:18.861855
# iter:17,gamma_gap:18.179655
# iter:18,gamma_gap:17.535349
# iter:19,gamma_gap:16.926156
# iter:20,gamma_gap:16.349531
# iter:21,gamma_gap:15.803125
# iter:22,gamma_gap:15.284728
# iter:23,gamma_gap:14.792193
# iter:24,gamma_gap:14.323310
# iter:25,gamma_gap:13.878633
# iter:26,gamma_gap:13.454863
# iter:27,gamma_gap:13.040369
# iter:28,gamma_gap:12.615767
# iter:29,gamma_gap:12.109170
# iter:30,gamma_gap:11.426684
# iter:31,gamma_gap:10.999132
# iter:32,gamma_gap:10.675167
# iter:33,gamma_gap:10.382267
# iter:34,gamma_gap:10.111578
# iter:35,gamma_gap:9.852848
# iter:36,gamma_gap:9.605470
# iter:37,gamma_gap:9.368838
# iter:38,gamma_gap:9.142359
# iter:39,gamma_gap:8.925474
# iter:40,gamma_gap:8.717658
# iter:41,gamma_gap:8.518805
# iter:42,gamma_gap:8.328175
# iter:43,gamma_gap:8.145177
# iter:44,gamma_gap:7.969420
# iter:45,gamma_gap:7.800533
# iter:46,gamma_gap:7.638165
# iter:47,gamma_gap:7.481983
# iter:48,gamma_gap:7.331662
# iter:49,gamma_gap:7.186889
# iter:50,gamma_gap:7.047348
# iter:51,gamma_gap:6.912717
# iter:52,gamma_gap:6.782647
# iter:53,gamma_gap:6.656735
# iter:54,gamma_gap:6.534467
# iter:55,gamma_gap:6.415103
# iter:56,gamma_gap:6.297408
# iter:57,gamma_gap:6.178938
# iter:58,gamma_gap:6.053815
# iter:59,gamma_gap:5.904192
# iter:60,gamma_gap:5.661956
# iter:61,gamma_gap:5.221958
# iter:62,gamma_gap:5.001854
# iter:63,gamma_gap:4.897038
# iter:64,gamma_gap:4.797222
# iter:65,gamma_gap:4.701919
# iter:66,gamma_gap:4.610749
# iter:67,gamma_gap:4.523395
# iter:68,gamma_gap:4.439585
# iter:69,gamma_gap:4.359082
# iter:70,gamma_gap:4.282458
# iter:71,gamma_gap:4.209568
# iter:72,gamma_gap:4.139266
# iter:73,gamma_gap:4.071403
# iter:74,gamma_gap:4.005833
# iter:75,gamma_gap:3.942410
# iter:76,gamma_gap:3.880976
# iter:77,gamma_gap:3.821352
# iter:78,gamma_gap:3.763319
# iter:79,gamma_gap:3.706576
# iter:80,gamma_gap:3.651467
# iter:81,gamma_gap:3.597996
# iter:82,gamma_gap:3.542903
# iter:83,gamma_gap:3.482750
# iter:84,gamma_gap:3.407841
# iter:85,gamma_gap:3.283497
# iter:86,gamma_gap:2.997607
# iter:87,gamma_gap:2.716289
# iter:88,gamma_gap:2.650117
# iter:89,gamma_gap:2.603970
# iter:90,gamma_gap:2.562224
# iter:91,gamma_gap:2.523213
# iter:92,gamma_gap:2.486870
# iter:93,gamma_gap:2.451426
# iter:94,gamma_gap:2.416801
# iter:95,gamma_gap:2.383652
# iter:96,gamma_gap:2.352054
# iter:97,gamma_gap:2.321201
# iter:98,gamma_gap:2.291093
# iter:99,gamma_gap:2.261728
# epsilon time:4.118095899999389
# omega time:0.2744194000006246
# phi time:0.2301432999993267
# pi time:0.031931099998473655
# iter:6,phi_gap:0.368319,pi_gap:0.006598,omega_gap:0.384199
# iter:0,gamma_gap:2.233100
# iter:1,gamma_gap:124.648454
# iter:2,gamma_gap:67.333763
# iter:3,gamma_gap:51.656322
# iter:4,gamma_gap:43.891273
# iter:5,gamma_gap:38.723366
# iter:6,gamma_gap:34.862833
# iter:7,gamma_gap:31.767754
# iter:8,gamma_gap:29.182559
# iter:9,gamma_gap:26.971504
# iter:10,gamma_gap:25.052417
# iter:11,gamma_gap:23.369588
# iter:12,gamma_gap:21.882085
# iter:13,gamma_gap:20.558287
# iter:14,gamma_gap:19.373037
# iter:15,gamma_gap:18.305963
# iter:16,gamma_gap:17.340377
# iter:17,gamma_gap:16.462501
# iter:18,gamma_gap:15.660886
# iter:19,gamma_gap:14.943794
# iter:20,gamma_gap:14.304496
# iter:21,gamma_gap:13.711716
# iter:22,gamma_gap:13.160502
# iter:23,gamma_gap:12.646607
# iter:24,gamma_gap:12.169628
# iter:25,gamma_gap:11.740882
# iter:26,gamma_gap:11.337345
# iter:27,gamma_gap:10.956891
# iter:28,gamma_gap:10.604200
# iter:29,gamma_gap:10.284121
# iter:30,gamma_gap:9.981185
# iter:31,gamma_gap:9.694113
# iter:32,gamma_gap:9.421758
# iter:33,gamma_gap:9.163090
# iter:34,gamma_gap:8.917180
# iter:35,gamma_gap:8.683331
# iter:36,gamma_gap:8.460715
# iter:37,gamma_gap:8.248495
# iter:38,gamma_gap:8.046040
# iter:39,gamma_gap:7.852769
# iter:40,gamma_gap:7.668145
# iter:41,gamma_gap:7.491671
# iter:42,gamma_gap:7.322888
# iter:43,gamma_gap:7.161367
# iter:44,gamma_gap:7.006710
# iter:45,gamma_gap:6.858542
# iter:46,gamma_gap:6.716516
# iter:47,gamma_gap:6.580300
# iter:48,gamma_gap:6.449586
# iter:49,gamma_gap:6.325083
# iter:50,gamma_gap:6.208964
# iter:51,gamma_gap:6.097139
# iter:52,gamma_gap:5.989363
# iter:53,gamma_gap:5.885387
# iter:54,gamma_gap:5.784948
# iter:55,gamma_gap:5.687755
# iter:56,gamma_gap:5.593457
# iter:57,gamma_gap:5.501593
# iter:58,gamma_gap:5.412185
# iter:59,gamma_gap:5.324085
# iter:60,gamma_gap:5.234133
# iter:61,gamma_gap:5.136716
# iter:62,gamma_gap:5.015044
# iter:63,gamma_gap:4.809716
# iter:64,gamma_gap:4.414581
# iter:65,gamma_gap:4.169063
# iter:66,gamma_gap:4.091748
# iter:67,gamma_gap:4.026082
# iter:68,gamma_gap:3.959705
# iter:69,gamma_gap:3.890655
# iter:70,gamma_gap:3.815037
# iter:71,gamma_gap:3.721851
# iter:72,gamma_gap:3.571630
# iter:73,gamma_gap:3.226986
# iter:74,gamma_gap:2.868852
# iter:75,gamma_gap:2.787792
# iter:76,gamma_gap:2.727379
# iter:77,gamma_gap:2.671230
# iter:78,gamma_gap:2.617890
# iter:79,gamma_gap:2.566710
# iter:80,gamma_gap:2.518896
# iter:81,gamma_gap:2.472944
# iter:82,gamma_gap:2.428401
# iter:83,gamma_gap:2.385173
# iter:84,gamma_gap:2.343184
# iter:85,gamma_gap:2.302370
# iter:86,gamma_gap:2.262676
# iter:87,gamma_gap:2.224053
# iter:88,gamma_gap:2.186458
# iter:89,gamma_gap:2.152330
# iter:90,gamma_gap:2.119253
# iter:91,gamma_gap:2.087101
# iter:92,gamma_gap:2.055837
# iter:93,gamma_gap:2.025425
# iter:94,gamma_gap:1.995833
# iter:95,gamma_gap:1.967031
# iter:96,gamma_gap:1.938991
# iter:97,gamma_gap:1.911687
# iter:98,gamma_gap:1.885095
# iter:99,gamma_gap:1.859191
# epsilon time:4.099993699999686
# omega time:0.28841149999971094
# phi time:0.23044220000156201
# pi time:0.03215289999934612
# iter:7,phi_gap:0.360742,pi_gap:0.006615,omega_gap:0.382245
# iter:0,gamma_gap:1.833955
# iter:1,gamma_gap:102.592836
# iter:2,gamma_gap:55.797421
# iter:3,gamma_gap:45.985962
# iter:4,gamma_gap:39.691958
# iter:5,gamma_gap:35.106933
# iter:6,gamma_gap:31.492659
# iter:7,gamma_gap:28.512291
# iter:8,gamma_gap:25.990901
# iter:9,gamma_gap:23.823951
# iter:10,gamma_gap:21.941161
# iter:11,gamma_gap:20.291316
# iter:12,gamma_gap:18.835223
# iter:13,gamma_gap:17.542021
# iter:14,gamma_gap:16.386974
# iter:15,gamma_gap:15.350023
# iter:16,gamma_gap:14.414750
# iter:17,gamma_gap:13.590148
# iter:18,gamma_gap:12.882728
# iter:19,gamma_gap:12.234705
# iter:20,gamma_gap:11.639541
# iter:21,gamma_gap:11.111156
# iter:22,gamma_gap:10.621962
# iter:23,gamma_gap:10.168083
# iter:24,gamma_gap:9.746159
# iter:25,gamma_gap:9.364488
# iter:26,gamma_gap:9.019726
# iter:27,gamma_gap:8.697077
# iter:28,gamma_gap:8.394697
# iter:29,gamma_gap:8.110945
# iter:30,gamma_gap:7.844356
# iter:31,gamma_gap:7.593613
# iter:32,gamma_gap:7.357530
# iter:33,gamma_gap:7.135033
# iter:34,gamma_gap:6.925149
# iter:35,gamma_gap:6.726991
# iter:36,gamma_gap:6.542763
# iter:37,gamma_gap:6.368973
# iter:38,gamma_gap:6.204371
# iter:39,gamma_gap:6.058394
# iter:40,gamma_gap:5.925918
# iter:41,gamma_gap:5.799692
# iter:42,gamma_gap:5.679355
# iter:43,gamma_gap:5.564566
# iter:44,gamma_gap:5.456577
# iter:45,gamma_gap:5.360854
# iter:46,gamma_gap:5.269024
# iter:47,gamma_gap:5.180879
# iter:48,gamma_gap:5.096215
# iter:49,gamma_gap:5.014836
# iter:50,gamma_gap:4.936549
# iter:51,gamma_gap:4.861157
# iter:52,gamma_gap:4.788457
# iter:53,gamma_gap:4.718230
# iter:54,gamma_gap:4.651625
# iter:55,gamma_gap:4.587658
# iter:56,gamma_gap:4.525035
# iter:57,gamma_gap:4.463216
# iter:58,gamma_gap:4.401348
# iter:59,gamma_gap:4.337939
# iter:60,gamma_gap:4.270032
# iter:61,gamma_gap:4.190769
# iter:62,gamma_gap:4.080584
# iter:63,gamma_gap:3.870301
# iter:64,gamma_gap:3.388686
# iter:65,gamma_gap:2.973671
# iter:66,gamma_gap:2.509102
# iter:67,gamma_gap:2.288480
# iter:68,gamma_gap:2.226938
# iter:69,gamma_gap:2.183275
# iter:70,gamma_gap:2.145456
# iter:71,gamma_gap:2.110642
# iter:72,gamma_gap:2.077731
# iter:73,gamma_gap:2.046267
# iter:74,gamma_gap:2.016037
# iter:75,gamma_gap:1.986922
# iter:76,gamma_gap:1.958925
# iter:77,gamma_gap:1.932169
# iter:78,gamma_gap:1.906232
# iter:79,gamma_gap:1.881084
# iter:80,gamma_gap:1.856695
# iter:81,gamma_gap:1.833038
# iter:82,gamma_gap:1.810087
# iter:83,gamma_gap:1.787817
# iter:84,gamma_gap:1.766206
# iter:85,gamma_gap:1.745231
# iter:86,gamma_gap:1.724871
# iter:87,gamma_gap:1.705107
# iter:88,gamma_gap:1.685920
# iter:89,gamma_gap:1.667292
# iter:90,gamma_gap:1.649206
# iter:91,gamma_gap:1.631647
# iter:92,gamma_gap:1.614599
# iter:93,gamma_gap:1.598048
# iter:94,gamma_gap:1.581980
# iter:95,gamma_gap:1.566382
# iter:96,gamma_gap:1.551242
# iter:97,gamma_gap:1.536547
# iter:98,gamma_gap:1.522288
# iter:99,gamma_gap:1.508453
# epsilon time:4.09927609999977
# omega time:0.2684912999993685
# phi time:0.22951710000052117
# pi time:0.032119700001203455
# iter:8,phi_gap:0.356653,pi_gap:0.006631,omega_gap:0.381028
# iter:0,gamma_gap:1.495059
# iter:1,gamma_gap:59.509772
# iter:2,gamma_gap:37.755163
# iter:3,gamma_gap:30.636977
# iter:4,gamma_gap:27.006732
# iter:5,gamma_gap:23.727818
# iter:6,gamma_gap:21.239629
# iter:7,gamma_gap:19.176664
# iter:8,gamma_gap:17.412820
# iter:9,gamma_gap:15.888959
# iter:10,gamma_gap:14.561487
# iter:11,gamma_gap:13.396904
# iter:12,gamma_gap:12.368834
# iter:13,gamma_gap:11.456186
# iter:14,gamma_gap:10.641914
# iter:15,gamma_gap:9.912111
# iter:16,gamma_gap:9.255345
# iter:17,gamma_gap:8.662142
# iter:18,gamma_gap:8.124596
# iter:19,gamma_gap:7.636064
# iter:20,gamma_gap:7.190920
# iter:21,gamma_gap:6.795993
# iter:22,gamma_gap:6.434199
# iter:23,gamma_gap:6.127612
# iter:24,gamma_gap:5.855707
# iter:25,gamma_gap:5.604352
# iter:26,gamma_gap:5.371742
# iter:27,gamma_gap:5.156276
# iter:28,gamma_gap:4.956524
# iter:29,gamma_gap:4.771207
# iter:30,gamma_gap:4.614410
# iter:31,gamma_gap:4.481613
# iter:32,gamma_gap:4.358536
# iter:33,gamma_gap:4.244406
# iter:34,gamma_gap:4.138510
# iter:35,gamma_gap:4.047945
# iter:36,gamma_gap:3.970201
# iter:37,gamma_gap:3.903287
# iter:38,gamma_gap:3.840496
# iter:39,gamma_gap:3.781335
# iter:40,gamma_gap:3.725196
# iter:41,gamma_gap:3.671226
# iter:42,gamma_gap:3.622377
# iter:43,gamma_gap:3.574235
# iter:44,gamma_gap:3.517121
# iter:45,gamma_gap:3.431585
# iter:46,gamma_gap:3.243815
# iter:47,gamma_gap:2.808380
# iter:48,gamma_gap:2.590719
# iter:49,gamma_gap:2.543094
# iter:50,gamma_gap:2.510402
# iter:51,gamma_gap:2.481990
# iter:52,gamma_gap:2.457269
# iter:53,gamma_gap:2.436644
# iter:54,gamma_gap:2.421058
# iter:55,gamma_gap:2.406613
# iter:56,gamma_gap:2.392953
# iter:57,gamma_gap:2.380034
# iter:58,gamma_gap:2.367831
# iter:59,gamma_gap:2.356322
# iter:60,gamma_gap:2.345491
# iter:61,gamma_gap:2.335323
# iter:62,gamma_gap:2.325804
# iter:63,gamma_gap:2.316921
# iter:64,gamma_gap:2.308662
# iter:65,gamma_gap:2.301018
# iter:66,gamma_gap:2.293978
# iter:67,gamma_gap:2.287534
# iter:68,gamma_gap:2.281677
# iter:69,gamma_gap:2.276400
# iter:70,gamma_gap:2.271697
# iter:71,gamma_gap:2.267561
# iter:72,gamma_gap:2.263987
# iter:73,gamma_gap:2.264177
# iter:74,gamma_gap:2.264928
# iter:75,gamma_gap:2.266080
# iter:76,gamma_gap:2.267633
# iter:77,gamma_gap:2.269606
# iter:78,gamma_gap:2.272295
# iter:79,gamma_gap:2.275358
# iter:80,gamma_gap:2.278795
# iter:81,gamma_gap:2.282599
# iter:82,gamma_gap:2.286762
# iter:83,gamma_gap:2.291266
# iter:84,gamma_gap:2.296089
# iter:85,gamma_gap:2.301193
# iter:86,gamma_gap:2.306521
# iter:87,gamma_gap:2.311987
# iter:88,gamma_gap:2.317455
# iter:89,gamma_gap:2.322709
# iter:90,gamma_gap:2.327386
# iter:91,gamma_gap:2.330833
# iter:92,gamma_gap:2.331783
# iter:93,gamma_gap:2.327459
# iter:94,gamma_gap:2.310705
# iter:95,gamma_gap:2.258560
# iter:96,gamma_gap:2.082745
# iter:97,gamma_gap:1.717755
# iter:98,gamma_gap:1.590571
# iter:99,gamma_gap:1.560436
# epsilon time:4.133202700000766
# omega time:0.2748135000001639
# phi time:0.23512789999949746
# pi time:0.03198239999983343
# iter:9,phi_gap:0.355580,pi_gap:0.006620,omega_gap:0.382422
# iter:0,gamma_gap:1.546026
# iter:1,gamma_gap:49.278347
# iter:2,gamma_gap:34.041086
# iter:3,gamma_gap:25.734831
# iter:4,gamma_gap:21.485624
# iter:5,gamma_gap:18.022514
# iter:6,gamma_gap:15.130731
# iter:7,gamma_gap:12.840220
# iter:8,gamma_gap:11.446757
# iter:9,gamma_gap:10.279742
# iter:10,gamma_gap:9.304532
# iter:11,gamma_gap:8.469657
# iter:12,gamma_gap:7.737569
# iter:13,gamma_gap:7.091088
# iter:14,gamma_gap:6.516599
# iter:15,gamma_gap:6.003210
# iter:16,gamma_gap:5.542122
# iter:17,gamma_gap:5.126166
# iter:18,gamma_gap:4.749447
# iter:19,gamma_gap:4.407073
# iter:20,gamma_gap:4.116987
# iter:21,gamma_gap:3.859175
# iter:22,gamma_gap:3.621072
# iter:23,gamma_gap:3.400757
# iter:24,gamma_gap:3.196562
# iter:25,gamma_gap:3.007026
# iter:26,gamma_gap:2.830866
# iter:27,gamma_gap:2.666943
# iter:28,gamma_gap:2.514246
# iter:29,gamma_gap:2.371869
# iter:30,gamma_gap:2.239001
# iter:31,gamma_gap:2.114907
# iter:32,gamma_gap:1.998925
# iter:33,gamma_gap:1.890452
# iter:34,gamma_gap:1.788941
# iter:35,gamma_gap:1.698878
# iter:36,gamma_gap:1.620533
# iter:37,gamma_gap:1.546859
# iter:38,gamma_gap:1.477542
# iter:39,gamma_gap:1.412291
# iter:40,gamma_gap:1.353517
# iter:41,gamma_gap:1.305401
# iter:42,gamma_gap:1.259962
# iter:43,gamma_gap:1.217040
# iter:44,gamma_gap:1.176488
# iter:45,gamma_gap:1.138167
# iter:46,gamma_gap:1.101948
# iter:47,gamma_gap:1.068813
# iter:48,gamma_gap:1.042663
# iter:49,gamma_gap:1.017891
# iter:50,gamma_gap:0.994427
# iter:51,gamma_gap:0.972205
# iter:52,gamma_gap:0.958536
# iter:53,gamma_gap:0.947835
# iter:54,gamma_gap:0.940122
# iter:55,gamma_gap:0.933319
# iter:56,gamma_gap:0.926971
# iter:57,gamma_gap:0.921133
# iter:58,gamma_gap:0.916436
# iter:59,gamma_gap:0.912080
# iter:60,gamma_gap:0.908054
# iter:61,gamma_gap:0.904350
# iter:62,gamma_gap:0.900960
# iter:63,gamma_gap:0.897875
# iter:64,gamma_gap:0.895089
# iter:65,gamma_gap:0.892595
# iter:66,gamma_gap:0.890386
# iter:67,gamma_gap:0.888459
# iter:68,gamma_gap:0.886808
# iter:69,gamma_gap:0.885428
# iter:70,gamma_gap:0.884317
# iter:71,gamma_gap:0.883471
# iter:72,gamma_gap:0.882887
# iter:73,gamma_gap:0.882563
# iter:74,gamma_gap:0.882498
# iter:75,gamma_gap:0.882690
# iter:76,gamma_gap:0.883138
# iter:77,gamma_gap:0.883842
# iter:78,gamma_gap:0.884803
# iter:79,gamma_gap:0.886020
# iter:80,gamma_gap:0.887494
# iter:81,gamma_gap:0.889228
# iter:82,gamma_gap:0.891223
# iter:83,gamma_gap:0.893480
# iter:84,gamma_gap:0.896003
# iter:85,gamma_gap:0.898795
# iter:86,gamma_gap:0.901859
# iter:87,gamma_gap:0.905199
# iter:88,gamma_gap:0.908820
# iter:89,gamma_gap:0.912726
# iter:90,gamma_gap:0.916923
# iter:91,gamma_gap:0.921417
# iter:92,gamma_gap:0.926213
# iter:93,gamma_gap:0.931319
# iter:94,gamma_gap:0.936742
# iter:95,gamma_gap:0.942489
# iter:96,gamma_gap:0.948569
# iter:97,gamma_gap:0.954991
# iter:98,gamma_gap:0.961764
# iter:99,gamma_gap:0.968898
# epsilon time:4.144548199999917
# omega time:0.28229040000042005
# phi time:0.22699879999890982
# pi time:0.030519800000547548
# iter:10,phi_gap:0.354107,pi_gap:0.006587,omega_gap:0.381165
# iter:0,gamma_gap:0.976404
# iter:1,gamma_gap:50.097343
# iter:2,gamma_gap:34.905076
# iter:3,gamma_gap:25.201737
# iter:4,gamma_gap:19.776857
# iter:5,gamma_gap:16.579894
# iter:6,gamma_gap:14.059954
# iter:7,gamma_gap:12.073544
# iter:8,gamma_gap:10.633043
# iter:9,gamma_gap:9.747190
# iter:10,gamma_gap:8.978260
# iter:11,gamma_gap:8.304390
# iter:12,gamma_gap:7.708784
# iter:13,gamma_gap:7.178330
# iter:14,gamma_gap:6.702597
# iter:15,gamma_gap:6.273046
# iter:16,gamma_gap:5.882312
# iter:17,gamma_gap:5.523284
# iter:18,gamma_gap:5.187186
# iter:19,gamma_gap:4.857372
# iter:20,gamma_gap:4.482528
# iter:21,gamma_gap:3.924324
# iter:22,gamma_gap:3.486761
# iter:23,gamma_gap:3.350546
# iter:24,gamma_gap:3.226585
# iter:25,gamma_gap:3.110799
# iter:26,gamma_gap:3.002960
# iter:27,gamma_gap:2.902719
# iter:28,gamma_gap:2.809704
# iter:29,gamma_gap:2.723544
# iter:30,gamma_gap:2.643881
# iter:31,gamma_gap:2.571701
# iter:32,gamma_gap:2.508067
# iter:33,gamma_gap:2.454617
# iter:34,gamma_gap:2.405711
# iter:35,gamma_gap:2.360876
# iter:36,gamma_gap:2.319411
# iter:37,gamma_gap:2.280096
# iter:38,gamma_gap:2.240454
# iter:39,gamma_gap:2.194544
# iter:40,gamma_gap:2.124953
# iter:41,gamma_gap:1.967537
# iter:42,gamma_gap:1.557681
# iter:43,gamma_gap:1.366465
# iter:44,gamma_gap:1.337460
# iter:45,gamma_gap:1.304010
# iter:46,gamma_gap:1.266052
# iter:47,gamma_gap:1.223818
# iter:48,gamma_gap:1.180483
# iter:49,gamma_gap:1.137612
# iter:50,gamma_gap:1.095996
# iter:51,gamma_gap:1.056025
# iter:52,gamma_gap:1.017872
# iter:53,gamma_gap:0.981587
# iter:54,gamma_gap:0.947152
# iter:55,gamma_gap:0.914514
# iter:56,gamma_gap:0.883596
# iter:57,gamma_gap:0.854856
# iter:58,gamma_gap:0.828314
# iter:59,gamma_gap:0.803098
# iter:60,gamma_gap:0.779685
# iter:61,gamma_gap:0.757846
# iter:62,gamma_gap:0.736981
# iter:63,gamma_gap:0.717047
# iter:64,gamma_gap:0.698005
# iter:65,gamma_gap:0.679816
# iter:66,gamma_gap:0.662447
# iter:67,gamma_gap:0.645865
# iter:68,gamma_gap:0.630040
# iter:69,gamma_gap:0.614943
# iter:70,gamma_gap:0.600549
# iter:71,gamma_gap:0.586832
# iter:72,gamma_gap:0.573771
# iter:73,gamma_gap:0.561345
# iter:74,gamma_gap:0.549533
# iter:75,gamma_gap:0.538318
# iter:76,gamma_gap:0.527683
# iter:77,gamma_gap:0.517614
# iter:78,gamma_gap:0.508096
# iter:79,gamma_gap:0.499116
# iter:80,gamma_gap:0.490664
# iter:81,gamma_gap:0.482730
# iter:82,gamma_gap:0.475304
# iter:83,gamma_gap:0.471040
# iter:84,gamma_gap:0.469080
# iter:85,gamma_gap:0.467595
# iter:86,gamma_gap:0.467106
# iter:87,gamma_gap:0.467046
# iter:88,gamma_gap:0.467420
# iter:89,gamma_gap:0.468233
# iter:90,gamma_gap:0.469494
# iter:91,gamma_gap:0.471212
# iter:92,gamma_gap:0.473398
# iter:93,gamma_gap:0.476065
# iter:94,gamma_gap:0.479229
# iter:95,gamma_gap:0.482907
# iter:96,gamma_gap:0.487120
# iter:97,gamma_gap:0.491889
# iter:98,gamma_gap:0.497240
# iter:99,gamma_gap:0.503201
# epsilon time:4.095069799999692
# omega time:0.2824393000009877
# phi time:0.2414730000000418
# pi time:0.0318554999994376
# iter:11,phi_gap:0.351553,pi_gap:0.006542,omega_gap:0.377903
# iter:0,gamma_gap:0.510243
# iter:1,gamma_gap:50.864830
# iter:2,gamma_gap:34.685543
# iter:3,gamma_gap:23.849505
# iter:4,gamma_gap:17.335209
# iter:5,gamma_gap:13.323838
# iter:6,gamma_gap:11.126032
# iter:7,gamma_gap:9.579017
# iter:8,gamma_gap:8.385733
# iter:9,gamma_gap:7.448901
# iter:10,gamma_gap:6.946493
# iter:11,gamma_gap:6.536168
# iter:12,gamma_gap:6.170237
# iter:13,gamma_gap:5.839566
# iter:14,gamma_gap:5.533907
# iter:15,gamma_gap:5.235554
# iter:16,gamma_gap:4.893700
# iter:17,gamma_gap:4.339612
# iter:18,gamma_gap:3.771495
# iter:19,gamma_gap:3.586293
# iter:20,gamma_gap:3.420673
# iter:21,gamma_gap:3.260898
# iter:22,gamma_gap:3.108946
# iter:23,gamma_gap:2.965732
# iter:24,gamma_gap:2.831479
# iter:25,gamma_gap:2.706008
# iter:26,gamma_gap:2.588921
# iter:27,gamma_gap:2.484053
# iter:28,gamma_gap:2.389877
# iter:29,gamma_gap:2.301702
# iter:30,gamma_gap:2.219107
# iter:31,gamma_gap:2.162386
# iter:32,gamma_gap:2.113783
# iter:33,gamma_gap:2.067882
# iter:34,gamma_gap:2.024532
# iter:35,gamma_gap:1.983595
# iter:36,gamma_gap:1.944945
# iter:37,gamma_gap:1.908467
# iter:38,gamma_gap:1.874060
# iter:39,gamma_gap:1.841629
# iter:40,gamma_gap:1.811090
# iter:41,gamma_gap:1.782365
# iter:42,gamma_gap:1.755382
# iter:43,gamma_gap:1.730075
# iter:44,gamma_gap:1.706384
# iter:45,gamma_gap:1.684249
# iter:46,gamma_gap:1.663779
# iter:47,gamma_gap:1.646883
# iter:48,gamma_gap:1.631223
# iter:49,gamma_gap:1.616737
# iter:50,gamma_gap:1.603345
# iter:51,gamma_gap:1.590931
# iter:52,gamma_gap:1.579323
# iter:53,gamma_gap:1.568246
# iter:54,gamma_gap:1.557230
# iter:55,gamma_gap:1.545414
# iter:56,gamma_gap:1.531061
# iter:57,gamma_gap:1.510217
# iter:58,gamma_gap:1.472218
# iter:59,gamma_gap:1.381099
# iter:60,gamma_gap:1.109488
# iter:61,gamma_gap:0.784750
# iter:62,gamma_gap:0.683382
# iter:63,gamma_gap:0.624081
# iter:64,gamma_gap:0.577348
# iter:65,gamma_gap:0.547918
# iter:66,gamma_gap:0.529525
# iter:67,gamma_gap:0.513191
# iter:68,gamma_gap:0.498148
# iter:69,gamma_gap:0.486621
# iter:70,gamma_gap:0.475081
# iter:71,gamma_gap:0.465840
# iter:72,gamma_gap:0.457090
# iter:73,gamma_gap:0.448127
# iter:74,gamma_gap:0.439073
# iter:75,gamma_gap:0.430021
# iter:76,gamma_gap:0.421040
# iter:77,gamma_gap:0.412182
# iter:78,gamma_gap:0.403484
# iter:79,gamma_gap:0.395296
# iter:80,gamma_gap:0.387306
# iter:81,gamma_gap:0.379511
# iter:82,gamma_gap:0.371915
# iter:83,gamma_gap:0.364522
# iter:84,gamma_gap:0.357334
# iter:85,gamma_gap:0.350347
# iter:86,gamma_gap:0.343561
# iter:87,gamma_gap:0.336970
# iter:88,gamma_gap:0.330570
# iter:89,gamma_gap:0.324356
# iter:90,gamma_gap:0.318323
# iter:91,gamma_gap:0.312864
# iter:92,gamma_gap:0.307564
# iter:93,gamma_gap:0.302430
# iter:94,gamma_gap:0.297441
# iter:95,gamma_gap:0.292571
# iter:96,gamma_gap:0.287818
# iter:97,gamma_gap:0.283177
# iter:98,gamma_gap:0.279519
# iter:99,gamma_gap:0.276181
# epsilon time:4.1205924000005325
# omega time:0.27049429999897256
# phi time:0.22734459999992396
# pi time:0.032100700000228244
# iter:12,phi_gap:0.347503,pi_gap:0.006496,omega_gap:0.372469
# iter:0,gamma_gap:0.272847
# iter:1,gamma_gap:52.212794
# iter:2,gamma_gap:32.708363
# iter:3,gamma_gap:20.835647
# iter:4,gamma_gap:13.611775
# iter:5,gamma_gap:9.711048
# iter:6,gamma_gap:7.476434
# iter:7,gamma_gap:6.199000
# iter:8,gamma_gap:5.377202
# iter:9,gamma_gap:4.750978
# iter:10,gamma_gap:4.381888
# iter:11,gamma_gap:4.087976
# iter:12,gamma_gap:3.836157
# iter:13,gamma_gap:3.617652
# iter:14,gamma_gap:3.434231
# iter:15,gamma_gap:3.282941
# iter:16,gamma_gap:3.146164
# iter:17,gamma_gap:3.039537
# iter:18,gamma_gap:2.937988
# iter:19,gamma_gap:2.841673
# iter:20,gamma_gap:2.750547
# iter:21,gamma_gap:2.664448
# iter:22,gamma_gap:2.583156
# iter:23,gamma_gap:2.506420
# iter:24,gamma_gap:2.433978
# iter:25,gamma_gap:2.365573
# iter:26,gamma_gap:2.300952
# iter:27,gamma_gap:2.239879
# iter:28,gamma_gap:2.182127
# iter:29,gamma_gap:2.127487
# iter:30,gamma_gap:2.075764
# iter:31,gamma_gap:2.026776
# iter:32,gamma_gap:1.980355
# iter:33,gamma_gap:1.936345
# iter:34,gamma_gap:1.894604
# iter:35,gamma_gap:1.854998
# iter:36,gamma_gap:1.817405
# iter:37,gamma_gap:1.781710
# iter:38,gamma_gap:1.747810
# iter:39,gamma_gap:1.715606
# iter:40,gamma_gap:1.685009
# iter:41,gamma_gap:1.655934
# iter:42,gamma_gap:1.628305
# iter:43,gamma_gap:1.602050
# iter:44,gamma_gap:1.577101
# iter:45,gamma_gap:1.553397
# iter:46,gamma_gap:1.530879
# iter:47,gamma_gap:1.509494
# iter:48,gamma_gap:1.489192
# iter:49,gamma_gap:1.469927
# iter:50,gamma_gap:1.451653
# iter:51,gamma_gap:1.434332
# iter:52,gamma_gap:1.417925
# iter:53,gamma_gap:1.402396
# iter:54,gamma_gap:1.387714
# iter:55,gamma_gap:1.373847
# iter:56,gamma_gap:1.360766
# iter:57,gamma_gap:1.348446
# iter:58,gamma_gap:1.336861
# iter:59,gamma_gap:1.325988
# iter:60,gamma_gap:1.315806
# iter:61,gamma_gap:1.306294
# iter:62,gamma_gap:1.297434
# iter:63,gamma_gap:1.289210
# iter:64,gamma_gap:1.281604
# iter:65,gamma_gap:1.274603
# iter:66,gamma_gap:1.268192
# iter:67,gamma_gap:1.262360
# iter:68,gamma_gap:1.257095
# iter:69,gamma_gap:1.252387
# iter:70,gamma_gap:1.248227
# iter:71,gamma_gap:1.244605
# iter:72,gamma_gap:1.241514
# iter:73,gamma_gap:1.238949
# iter:74,gamma_gap:1.236902
# iter:75,gamma_gap:1.235368
# iter:76,gamma_gap:1.234343
# iter:77,gamma_gap:1.233824
# iter:78,gamma_gap:1.233806
# iter:79,gamma_gap:1.234288
# iter:80,gamma_gap:1.235268
# iter:81,gamma_gap:1.236742
# iter:82,gamma_gap:1.238711
# iter:83,gamma_gap:1.241174
# iter:84,gamma_gap:1.244128
# iter:85,gamma_gap:1.247573
# iter:86,gamma_gap:1.251507
# iter:87,gamma_gap:1.255927
# iter:88,gamma_gap:1.260831
# iter:89,gamma_gap:1.266212
# iter:90,gamma_gap:1.272062
# iter:91,gamma_gap:1.278368
# iter:92,gamma_gap:1.285111
# iter:93,gamma_gap:1.292262
# iter:94,gamma_gap:1.299778
# iter:95,gamma_gap:1.307593
# iter:96,gamma_gap:1.315606
# iter:97,gamma_gap:1.323657
# iter:98,gamma_gap:1.331486
# iter:99,gamma_gap:1.338642
# epsilon time:4.11508159999903
# omega time:0.26758979999976873
# phi time:0.22592450000047393
# pi time:0.03217979999863019
# iter:13,phi_gap:0.343462,pi_gap:0.006460,omega_gap:0.364386
# iter:0,gamma_gap:1.344302
# iter:1,gamma_gap:52.522552
# iter:2,gamma_gap:31.043266
# iter:3,gamma_gap:18.829545
# iter:4,gamma_gap:11.690731
# iter:5,gamma_gap:7.425631
# iter:6,gamma_gap:5.045988
# iter:7,gamma_gap:3.918855
# iter:8,gamma_gap:3.195765
# iter:9,gamma_gap:2.707756
# iter:10,gamma_gap:2.408458
# iter:11,gamma_gap:2.237955
# iter:12,gamma_gap:2.128090
# iter:13,gamma_gap:2.036135
# iter:14,gamma_gap:1.960217
# iter:15,gamma_gap:1.908301
# iter:16,gamma_gap:1.865893
# iter:17,gamma_gap:1.829382
# iter:18,gamma_gap:1.794768
# iter:19,gamma_gap:1.762462
# iter:20,gamma_gap:1.732663
# iter:21,gamma_gap:1.705435
# iter:22,gamma_gap:1.680758
# iter:23,gamma_gap:1.658549
# iter:24,gamma_gap:1.638674
# iter:25,gamma_gap:1.620931
# iter:26,gamma_gap:1.605031
# iter:27,gamma_gap:1.590517
# iter:28,gamma_gap:1.576609
# iter:29,gamma_gap:1.561824
# iter:30,gamma_gap:1.542944
# iter:31,gamma_gap:1.511709
# iter:32,gamma_gap:1.442040
# iter:33,gamma_gap:1.239581
# iter:34,gamma_gap:0.815686
# iter:35,gamma_gap:0.690790
# iter:36,gamma_gap:0.686637
# iter:37,gamma_gap:0.674287
# iter:38,gamma_gap:0.656283
# iter:39,gamma_gap:0.636829
# iter:40,gamma_gap:0.618649
# iter:41,gamma_gap:0.601115
# iter:42,gamma_gap:0.584505
# iter:43,gamma_gap:0.568906
# iter:44,gamma_gap:0.554325
# iter:45,gamma_gap:0.540731
# iter:46,gamma_gap:0.528076
# iter:47,gamma_gap:0.516307
# iter:48,gamma_gap:0.505369
# iter:49,gamma_gap:0.495207
# iter:50,gamma_gap:0.486291
# iter:51,gamma_gap:0.478967
# iter:52,gamma_gap:0.472104
# iter:53,gamma_gap:0.465685
# iter:54,gamma_gap:0.459691
# iter:55,gamma_gap:0.454104
# iter:56,gamma_gap:0.448908
# iter:57,gamma_gap:0.444087
# iter:58,gamma_gap:0.439625
# iter:59,gamma_gap:0.435509
# iter:60,gamma_gap:0.431726
# iter:61,gamma_gap:0.428263
# iter:62,gamma_gap:0.425110
# iter:63,gamma_gap:0.422257
# iter:64,gamma_gap:0.419694
# iter:65,gamma_gap:0.417413
# iter:66,gamma_gap:0.415407
# iter:67,gamma_gap:0.413669
# iter:68,gamma_gap:0.412194
# iter:69,gamma_gap:0.410976
# iter:70,gamma_gap:0.410012
# iter:71,gamma_gap:0.409297
# iter:72,gamma_gap:0.408830
# iter:73,gamma_gap:0.408608
# iter:74,gamma_gap:0.408781
# iter:75,gamma_gap:0.409294
# iter:76,gamma_gap:0.410026
# iter:77,gamma_gap:0.410981
# iter:78,gamma_gap:0.412161
# iter:79,gamma_gap:0.413571
# iter:80,gamma_gap:0.415214
# iter:81,gamma_gap:0.417096
# iter:82,gamma_gap:0.419221
# iter:83,gamma_gap:0.421595
# iter:84,gamma_gap:0.424225
# iter:85,gamma_gap:0.427118
# iter:86,gamma_gap:0.430280
# iter:87,gamma_gap:0.433721
# iter:88,gamma_gap:0.437449
# iter:89,gamma_gap:0.441474
# iter:90,gamma_gap:0.445807
# iter:91,gamma_gap:0.450458
# iter:92,gamma_gap:0.455441
# iter:93,gamma_gap:0.460769
# iter:94,gamma_gap:0.466457
# iter:95,gamma_gap:0.472519
# iter:96,gamma_gap:0.478974
# iter:97,gamma_gap:0.485838
# iter:98,gamma_gap:0.493132
# iter:99,gamma_gap:0.500878
# epsilon time:4.130427999998574
# omega time:0.27768990000004123
# phi time:0.23534900000049674
# pi time:0.031602099999872735
# iter:14,phi_gap:0.339833,pi_gap:0.006472,omega_gap:0.355232
# iter:0,gamma_gap:0.509097
# iter:1,gamma_gap:50.686071
# iter:2,gamma_gap:28.336433
# iter:3,gamma_gap:16.352914
# iter:4,gamma_gap:9.694690
# iter:5,gamma_gap:5.900189
# iter:6,gamma_gap:3.696535
# iter:7,gamma_gap:2.579438
# iter:8,gamma_gap:1.928173
# iter:9,gamma_gap:1.560389
# iter:10,gamma_gap:1.350182
# iter:11,gamma_gap:1.226863
# iter:12,gamma_gap:1.138390
# iter:13,gamma_gap:1.073437
# iter:14,gamma_gap:1.025866
# iter:15,gamma_gap:0.995053
# iter:16,gamma_gap:0.961413
# iter:17,gamma_gap:0.894873
# iter:18,gamma_gap:0.701323
# iter:19,gamma_gap:0.348802
# iter:20,gamma_gap:0.191480
# epsilon time:4.123624600000767
# omega time:0.2760208999989118
# phi time:0.23831799999970826
# pi time:0.031214700000418816
# iter:15,phi_gap:0.334357,pi_gap:0.006555,omega_gap:0.346325
# iter:0,gamma_gap:0.128409
# epsilon time:4.087846299999001
# omega time:0.2668313999984093
# phi time:0.23163390000081563
# pi time:0.0337160999988555
# iter:16,phi_gap:0.321015,pi_gap:0.006648,omega_gap:0.334217
# iter:0,gamma_gap:49.125900
# iter:1,gamma_gap:74.298355
# iter:2,gamma_gap:39.783551
# iter:3,gamma_gap:22.348014
# iter:4,gamma_gap:13.171682
# iter:5,gamma_gap:7.950006
# iter:6,gamma_gap:4.904129
# iter:7,gamma_gap:3.116401
# iter:8,gamma_gap:2.054396
# iter:9,gamma_gap:1.423135
# iter:10,gamma_gap:1.001631
# iter:11,gamma_gap:0.712498
# iter:12,gamma_gap:0.511936
# iter:13,gamma_gap:0.371366
# iter:14,gamma_gap:0.271893
# iter:15,gamma_gap:0.200872
# iter:16,gamma_gap:0.149738
# epsilon time:4.104874200000268
# omega time:0.2740469000000303
# phi time:0.22775129999899946
# pi time:0.031377299999803654
# iter:17,phi_gap:0.304692,pi_gap:0.006731,omega_gap:0.322420
# iter:0,gamma_gap:0.112629
# epsilon time:4.136790500000643
# omega time:0.2721746000006533
# phi time:0.2291122999995423
# pi time:0.03211060000103316
# iter:18,phi_gap:0.290110,pi_gap:0.006747,omega_gap:0.309300
# iter:0,gamma_gap:50.150905
# iter:1,gamma_gap:75.161513
# iter:2,gamma_gap:38.699787
# iter:3,gamma_gap:20.814250
# iter:4,gamma_gap:12.265245
# iter:5,gamma_gap:7.758039
# iter:6,gamma_gap:5.053248
# iter:7,gamma_gap:3.378182
# iter:8,gamma_gap:2.351228
# iter:9,gamma_gap:1.664433
# iter:10,gamma_gap:1.213944
# iter:11,gamma_gap:0.899763
# iter:12,gamma_gap:0.672450
# iter:13,gamma_gap:0.506526
# iter:14,gamma_gap:0.384425
# iter:15,gamma_gap:0.297386
# iter:16,gamma_gap:0.237200
# iter:17,gamma_gap:0.192781
# epsilon time:4.108423799998491
# omega time:0.2749257999985275
# phi time:0.24619159999929252
# pi time:0.03027690000089933
# iter:19,phi_gap:0.279476,pi_gap:0.006614,omega_gap:0.296970
# iter:0,gamma_gap:0.158324
# epsilon time:4.104790100000173
# omega time:0.26994789999844215
# phi time:0.22876679999899352
# pi time:0.032506999999895925
# iter:20,phi_gap:0.270277,pi_gap:0.006431,omega_gap:0.286719
# iter:0,gamma_gap:49.772380
# iter:1,gamma_gap:72.065913
# iter:2,gamma_gap:36.768359
# iter:3,gamma_gap:20.481133
# iter:4,gamma_gap:12.543091
# iter:5,gamma_gap:7.995408
# iter:6,gamma_gap:5.459188
# iter:7,gamma_gap:3.928524
# iter:8,gamma_gap:2.858452
# iter:9,gamma_gap:2.101348
# iter:10,gamma_gap:1.559366
# iter:11,gamma_gap:1.169230
# iter:12,gamma_gap:0.898071
# iter:13,gamma_gap:0.694936
# iter:14,gamma_gap:0.541617
# iter:15,gamma_gap:0.425045
# iter:16,gamma_gap:0.335783
# iter:17,gamma_gap:0.266966
# iter:18,gamma_gap:0.214170
# iter:19,gamma_gap:0.179128
# epsilon time:4.099353999999948
# omega time:0.2674771999991208
# phi time:0.23189339999953518
# pi time:0.03148030000011204
# iter:21,phi_gap:0.259504,pi_gap:0.006282,omega_gap:0.278849
# iter:0,gamma_gap:0.151288
# epsilon time:4.116052599998511
# omega time:0.2955658000009862
# phi time:0.2662694000009651
# pi time:0.03506319999905827
# iter:22,phi_gap:0.249134,pi_gap:0.006145,omega_gap:0.270175
# iter:0,gamma_gap:50.955558
# iter:1,gamma_gap:71.464123
# iter:2,gamma_gap:34.212588
# iter:3,gamma_gap:18.983940
# iter:4,gamma_gap:11.809394
# iter:5,gamma_gap:7.815216
# iter:6,gamma_gap:5.363723
# iter:7,gamma_gap:3.867305
# iter:8,gamma_gap:2.825769
# iter:9,gamma_gap:2.118461
# iter:10,gamma_gap:1.604573
# iter:11,gamma_gap:1.227173
# iter:12,gamma_gap:0.946926
# iter:13,gamma_gap:0.737612
# iter:14,gamma_gap:0.582236
# iter:15,gamma_gap:0.462519
# iter:16,gamma_gap:0.374165
# iter:17,gamma_gap:0.309597
# iter:18,gamma_gap:0.257550
# iter:19,gamma_gap:0.215281
# iter:20,gamma_gap:0.182099
# epsilon time:4.478310099999362
# omega time:0.30562649999956193
# phi time:0.23992120000002615
# pi time:0.03258559999994759
# iter:23,phi_gap:0.241702,pi_gap:0.006162,omega_gap:0.262050
# iter:0,gamma_gap:0.154909
# epsilon time:4.226369100000738
# omega time:0.2929007000002457
# phi time:0.24772899999879883
# pi time:0.034098699999958626
# iter:24,phi_gap:0.234751,pi_gap:0.006270,omega_gap:0.253573
# iter:0,gamma_gap:54.492529
# iter:1,gamma_gap:71.727677
# iter:2,gamma_gap:33.297410
# iter:3,gamma_gap:18.990516
# iter:4,gamma_gap:11.767948
# iter:5,gamma_gap:7.624383
# iter:6,gamma_gap:5.062093
# iter:7,gamma_gap:3.445684
# iter:8,gamma_gap:2.404682
# iter:9,gamma_gap:1.737755
# iter:10,gamma_gap:1.304068
# iter:11,gamma_gap:0.991412
# iter:12,gamma_gap:0.762307
# iter:13,gamma_gap:0.594126
# iter:14,gamma_gap:0.469013
# iter:15,gamma_gap:0.378644
# iter:16,gamma_gap:0.312911
# iter:17,gamma_gap:0.260395
# iter:18,gamma_gap:0.217835
# iter:19,gamma_gap:0.182952
# epsilon time:4.354297699999734
# omega time:0.2835082000001421
# phi time:0.2667366999994556
# pi time:0.0339774000003672
# iter:25,phi_gap:0.221214,pi_gap:0.006201,omega_gap:0.242463
# iter:0,gamma_gap:0.154219
# epsilon time:4.264751700000488
# omega time:0.27809849999903236
# phi time:0.2389515000013489
# pi time:0.032378399999288376
# iter:26,phi_gap:0.207903,pi_gap:0.006165,omega_gap:0.231859
# iter:0,gamma_gap:51.177072
# iter:1,gamma_gap:65.550150
# iter:2,gamma_gap:34.011153
# iter:3,gamma_gap:20.053059
# iter:4,gamma_gap:12.314087
# iter:5,gamma_gap:7.810127
# iter:6,gamma_gap:5.061089
# iter:7,gamma_gap:3.119195
# iter:8,gamma_gap:1.777936
# iter:9,gamma_gap:1.099893
# iter:10,gamma_gap:0.724378
# iter:11,gamma_gap:0.513333
# iter:12,gamma_gap:0.374564
# iter:13,gamma_gap:0.276438
# iter:14,gamma_gap:0.205604
# iter:15,gamma_gap:0.153946
# epsilon time:4.318250000000262
# omega time:0.30824390000088897
# phi time:0.2971025999995618
# pi time:0.03721480000058364
# iter:27,phi_gap:0.198608,pi_gap:0.006276,omega_gap:0.224514
# iter:0,gamma_gap:0.115943
# epsilon time:4.242839799999274
# omega time:0.27625979999902484
# phi time:0.23209359999964363
# pi time:0.03128379999907338
# iter:28,phi_gap:0.190495,pi_gap:0.006392,omega_gap:0.217230
# iter:0,gamma_gap:49.027253
# iter:1,gamma_gap:67.013956
# iter:2,gamma_gap:34.298488
# iter:3,gamma_gap:20.025434
# iter:4,gamma_gap:12.053400
# iter:5,gamma_gap:7.459474
# iter:6,gamma_gap:4.635921
# iter:7,gamma_gap:2.891286
# iter:8,gamma_gap:1.809143
# iter:9,gamma_gap:1.135807
# iter:10,gamma_gap:0.715657
# iter:11,gamma_gap:0.506427
# iter:12,gamma_gap:0.371028
# iter:13,gamma_gap:0.285238
# iter:14,gamma_gap:0.229282
# iter:15,gamma_gap:0.198849
# epsilon time:4.1214772000002995
# omega time:0.293722100001105
# phi time:0.25525700000071083
# pi time:0.03408029999991413
# iter:29,phi_gap:0.185052,pi_gap:0.006510,omega_gap:0.212391

# %%
# derive expectation from posterior (variational) distribution
theta=gamma/gamma.sum()
theta=theta.reshape(K,K)

# %% [markdown]
# # evaluation

# %% [markdown]
# ## utils

# %%
with open('data/Cora_enrich/tokens_3876.pickle','rb') as f:
    tokens=pickle.load(f)
tokens=np.array(tokens)

# %%
labels=[]
with open('data/Cora_enrich/labels.txt') as f:
    for line in f:
        labels.append(line.strip())
labels=np.array(labels)
labels_mini=labels[:100]

# %%
def get_top_tokens(phi,tokens,top=10):
    results=[]
    for i in range(phi.shape[0]):
        results.append(tokens[np.argsort(-phi[i,:])[:top]])
    return results

# %%
def get_top_docs(omega,labels,top=10):
    results=[]
    for i in range(omega.shape[0]):
        results.append(labels[np.argsort(-omega[i,:])[:top]])
    return results

# %% [markdown]
# ## evaluate

# %%
theta
# Out:
# array([[1.54988442e-01, 1.84179361e-06, 1.84179361e-06, 1.84179361e-06,
#         1.84179361e-06, 1.84179361e-06, 1.84179361e-06],
#        [1.84179361e-06, 2.11502536e-01, 1.84179361e-06, 1.84179361e-06,
#         1.84179361e-06, 1.84179361e-06, 1.84179361e-06],
#        [1.84179361e-06, 1.84179361e-06, 1.53836132e-01, 1.84179361e-06,
#         3.72236338e-02, 1.84179361e-06, 1.84179361e-06],
#        [1.84179361e-06, 1.84179361e-06, 1.84179361e-06, 1.26098837e-01,
#         1.84179361e-06, 1.84179361e-06, 1.84179361e-06],
#        [1.84179361e-06, 1.84179361e-06, 1.84179361e-06, 1.84179361e-06,
#         1.84179361e-06, 1.84179361e-06, 1.84179361e-06],
#        [1.84179361e-06, 1.84179361e-06, 1.84179361e-06, 1.84179361e-06,
#         1.84179361e-06, 7.55227321e-02, 1.84179361e-06],
#        [1.84179361e-06, 6.68002006e-02, 1.14633733e-02, 5.73865877e-02,
#         1.84179361e-06, 1.84179361e-06, 1.05105695e-01]])

# %%
get_top_tokens(phi,tokens,20)
# Out:
# [array(['class', 'distribut', 'probabl', 'bound', 'case', 'theori',
#         'concept', 'given', 'instanc', 'queri', 'bayesian', 'sampl',
#         'condit', 'follow', 'consid', 'theorem', 'number', 'work', 'relat',
#         'definit'], dtype='<U15'),
#  array(['network', 'data', 'train', 'neural', 'featur', 'tree', 'input',
#         'et', 'weight', 'al', 'estim', 'rule', 'error', 'valu', 'perform',
#         'test', 'classif', 'predict', 'linear', 'classifi'], dtype='<U15'),
#  array(['gen', 'knowledg', 'program', 'domain', 'rule', 'task', 'process',
#         'robot', 'search', 'state', 'solv', 'agent', 'strategi', 'action',
#         'induct', 'control', 'represent', 'design', 'behavior', 'oper'],
#        dtype='<U15'),
#  array(['genet', 'number', 'program', 'fit', 'perform', 'sequenc', 'ga',
#         'size', 'optim', 'popul', 'select', 'point', 'code', 'data',
#         'time', 'neural', 'comput', 'error', 'studi', 'work'], dtype='<U15'),
#  array(['case', 'reason', 'plan', 'explan', 'similar', 'adapt', 'retriev',
#         'structur', 'design', 'theori', 'process', 'object', 'goal', 'new',
#         'memori', 'provid', 'causal', 'featur', 'map', 'belief'],
#        dtype='<U15'),
#  array(['network', 'time', 'control', 'state', 'solut', 'architectur',
#         'local', 'comput', 'optim', 'dynam', 'implement', 'represent',
#         'order', 'unit', 'number', 'applic', 'connect', 'parallel',
#         'schedul', 'task'], dtype='<U15'),
#  array(['et', 'al', 'cell', 'neuron', 'visual', 'activ', 'field', 'direct',
#         'input', 'locat', 'spatial', 'inform', 'signal', 'cortex',
#         'review', 'process', 'orient', 'effect', 'map', 'place'],
#        dtype='<U15')]

# %%
get_top_docs(omega,labels,10)
# Out:
# [array(['Theory', 'Probabilistic_Methods', 'Theory', 'Rule_Learning',
#         'Probabilistic_Methods', 'Theory', 'Theory', 'Theory', 'Theory',
#         'Probabilistic_Methods'], dtype='<U22'),
#  array(['Theory', 'Neural_Networks', 'Probabilistic_Methods', 'Theory',
#         'Neural_Networks', 'Theory', 'Neural_Networks', 'Neural_Networks',
#         'Theory', 'Theory'], dtype='<U22'),
#  array(['Genetic_Algorithms', 'Reinforcement_Learning', 'Rule_Learning',
#         'Reinforcement_Learning', 'Reinforcement_Learning',
#         'Reinforcement_Learning', 'Case_Based', 'Theory',
#         'Genetic_Algorithms', 'Theory'], dtype='<U22'),
#  array(['Genetic_Algorithms', 'Genetic_Algorithms', 'Genetic_Algorithms',
#         'Genetic_Algorithms', 'Genetic_Algorithms', 'Neural_Networks',
#         'Genetic_Algorithms', 'Genetic_Algorithms', 'Neural_Networks',
#         'Genetic_Algorithms'], dtype='<U22'),
#  array(['Case_Based', 'Probabilistic_Methods', 'Case_Based', 'Case_Based',
#         'Case_Based', 'Case_Based', 'Rule_Learning', 'Case_Based',
#         'Neural_Networks', 'Case_Based'], dtype='<U22'),
#  array(['Genetic_Algorithms', 'Reinforcement_Learning',
#         'Reinforcement_Learning', 'Rule_Learning', 'Neural_Networks',
#         'Neural_Networks', 'Genetic_Algorithms', 'Neural_Networks',
#         'Neural_Networks', 'Rule_Learning'], dtype='<U22'),
#  array(['Neural_Networks', 'Neural_Networks', 'Neural_Networks',
#         'Neural_Networks', 'Neural_Networks', 'Neural_Networks',
#         'Probabilistic_Methods', 'Neural_Networks', 'Genetic_Algorithms',
#         'Neural_Networks'], dtype='<U22')]

# %%
pi
# Out:
# array([0.17951863, 0.21200674, 0.15018488, 0.2016221 , 0.06841285,
#        0.1479296 , 0.04032521])
